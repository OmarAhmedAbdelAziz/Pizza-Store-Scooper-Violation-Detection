# %%
import gdown
import os
import cv2
from pathlib import Path
from ultralytics import YOLO
from roboflow import Roboflow
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
rf = Roboflow(api_key="R74jhKNUxfJpMqRD85bY")
project = rf.workspace("pizza-use-case").project("pizzastore")
version = project.version(4)
dataset = version.download("yolov8")

# %%
# !yolo detect train model=yolov8n.pt data=/content/PizzaStore-4/data.yaml epochs=100 imgsz=640 batch=16 device=0
# Out:
# ...
# 100% 6.25M/6.25M [00:00<00:00, 110MB/s]
# Ultralytics 8.3.153 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo detect predict model=/content/runs/detect/train/weights/best.pt source=/content/downloaded_videos/saah.mp4
# Out:
# Ultralytics 8.3.153 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/617) /content/downloaded_videos/saah.mp4: 384x640 1 person, 3 pizzas, 45.0ms
# video 1/1 (frame 2/617) /content/downloaded_videos/saah.mp4: 384x640 1 person, 3 pizzas, 7.0ms
# video 1/1 (frame 3/617) /content/downloaded_videos/saah.mp4: 384x640 1 person, 3 pizzas, 9.1ms
# video 1/1 (frame 4/617) /content/downloaded_videos/saah.mp4: 384x640 1 person, 3 pizzas, 6.5ms
# video 1/1 (frame 5/617) /content/downloaded_videos/saah.mp4: 384x640 1 person, 3 pizzas, 7.0ms
# video 1/1 (frame 6/617) /content/downloaded_videos/saah.mp4: 384x640 1 hand, 1 person, 3 pizzas, 6.4ms
# video 1/1 (frame 7/617) /content/downloaded_videos/saah.mp4: 384x640 1 hand, 1 person, 3 pizzas, 8.0ms
# video 1/1 (frame 8/617) /content/downloaded_videos/saah.mp4: 384x640 1 person, 3 pizzas, 6.8ms
# ...
